# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahlz01/The-Last-Bastion-Alien-War/blob/main/NYT_Best_Restaurants_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
import seaborn
import matplotlib.pyplot as plt

url = '/content/nytimes_best_restaurants_2024.csv'

restaurant = pandas.read_csv(url, sep = ',')
restaurant.head()
# Out:
#               restaurant_name           city state  \
# 0  Mr. Baan’s Bar and Mookata        Phoenix    AZ
# 1                     Fikscue        Alameda    CA
# 2                      Azizam    Los Angeles    CA
# 3                     Camélia    Los Angeles    CA
# 4                  Four Kings  San Francisco    CA
#
#                                       address  \
# 0     218 E Portland St #B, Phoenix, AZ 85004
# 1     1708 Park St Ste 120, Alameda, CA 94501
# 2   2943 W Sunset Blvd, Los Angeles, CA 90026
# 3   1850 Industrial St, Los Angeles, CA 90021
# 4  710 Commercial St, San Francisco, CA 94108
#
#                                          description     cuisine_type  \
# 0  Mr. Baan’s Bar and Mookata offers a vibrant at...             Thai
# 1  Fikscue is a vibrant Indonesian-Texan barbecue...         Indo-Tex
# 2  Azizam is a cozy Persian eatery nestled in Sil...          Persian
# 3  Camélia is a charming French-Japanese bistro i...  French-Japanese
# ...

# %%
restaurant.describe()

restaurant['city'] = restaurant['city'].astype(str)
city = restaurant.groupby('city')['restaurant_name'].size().sort_values(ascending=False).head(20)
city.plot(kind='bar', title = 'City vs. Restaurant Count')

plt.xlabel('City')
plt.ylabel('Restaurant Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# This graph displays the distribution of restaurants per city.

# %%
restaurant.describe()

restaurant['state'] = restaurant['state'].astype(str)
state = restaurant.groupby('state')['restaurant_name'].size().sort_values(ascending=False).head(5)
state.plot(kind='line', title = 'Top 5 States with the Highest Restaurant Count')

plt.xlabel('State')
plt.ylabel('Restaurant Count')
plt.show()

# %% [markdown]
# This graph displays the distribution of restaurants per state.

# %%
restaurant.describe()

restaurant['cuisine_type'] = restaurant['cuisine_type'].astype(str)
cuisine = restaurant.groupby('cuisine_type')['restaurant_name'].size().sort_values(ascending=False)
cuisine.plot(kind='bar', title = 'Cuisine Type vs. Restaurant Count')

plt.xlabel('Cuisine Type')
plt.ylabel('Restaurant Count')
plt.show()

# %% [markdown]
# This graph reflects the number of restaurants that have the cuisine type.

# %%
restaurant.describe()

restaurant['cuisine_type'] = restaurant['cuisine_type'].astype(str)
cuisine = restaurant.groupby('cuisine_type')['restaurant_name'].size().sort_values(ascending=False)
cuisine.plot(kind='pie', title = 'Cuisine Type Distribution')

plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# This chart represents the cuisine distribution of the restaurants.
